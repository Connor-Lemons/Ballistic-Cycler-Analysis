# %%
import numpy as np
import matplotlib.pyplot as plt
import yapss
from yapss import math
import time as timing
import multiprocessing as mp

mu = 1.2150584270572e-2
C_value = 3.151175879508174
W_v = 1
W_th = 1

def solve_problem(angle):
    start = timing.time()
    problem = yapss.Problem(name="Simple_Cycler", nx=[6], nd = 3, nq = [1])
    mu = 1.2150584270572e-2

    theta = np.radians(angle)
    phi = theta/2

    def objective(arg):
        xi, yi, zi, vxi, vyi, vzi = arg.phase[0].initial_state
        xf, yf, zf, vxf, vyf, vzf = arg.phase[0].final_state
        tgt = [0, math.cos(-theta), math.sin(-theta)]
        c1, c2, c3 = math.cross([vxi, vyi, vzi], [vxf, vyf, vzf])
        t1, t2, t3 = math.cross([vxi, vyi, vzi], tgt)

        r1 = math.sqrt((xf + mu)**2 + yf**2 + zf**2)
        r2 = math.sqrt((xf - 1 + mu)**2 + yf**2 + zf**2)
        U = -0.5*(xf**2 + yf**2) - (1 - mu)/r1 - mu/r2

        Cf = -2*U - (vxf**2 + vyf**2 + vzf**2)
        arg.objective = W_v*(c1**2 + c2**2 + c3**2) + arg.phase[0].integral[0]

    def continuous(arg):
        x, y, z, vx, vy, vz = arg.phase[0].state

        r1 = math.sqrt((x + mu)**2 + y**2 + z**2)
        r2 = math.sqrt((x - 1 + mu)**2 + y**2 + z**2)
        U = -0.5*(x**2 + y**2) - (1 - mu)/r1 - mu/r2

        ax = x - (1 - mu)*(x + mu)/r1**3 - mu*(x - 1 + mu)/r2**3 + 2*vy
        ay = y - (1 - mu)*y/r1**3 - mu*y/r2**3 - 2*vx
        az = -(1 - mu)*z/r1**3 - mu*z/r2**3

        C = -2*U - (vx**2 + vy**2 + vz**2)

        arg.phase[0].dynamics = [vx, vy, vz, ax, ay, az]
        arg.phase[0].integrand = -W_th*z**2

    def discrete(arg):
        xi, yi, zi, vxi, vyi, vzi = arg.phase[0].initial_state
        xf, yf, zf, vxf, vyf, vzf = arg.phase[0].final_state
        c1, c2, c3 = math.cross([vxi, vyi, vzi], [vxf, vyf, vzf])
        arg.discrete = [xf-xi, yf-yi, zf-zi]

    problem.functions.objective = objective
    problem.functions.continuous = continuous
    problem.functions.discrete = discrete

    def day_to_gen(t):
        return t*2*math.pi/27.321661
    def gen_to_day(t):
        return t*27.321661/2/math.pi

    bounds = problem.bounds.phase[0]
    bounds.initial_time.lower = bounds.initial_time.upper = 0
    problem.bounds.discrete.lower[:] = problem.bounds.discrete.upper[:] = [0, 0, 0]

    load_tgt = "2dorbit.npz"

    guess_sol = np.load(load_tgt)
    state_guess = guess_sol["state"]
    state_guess_3d = np.zeros(tuple(x + y for x, y in zip(np.shape(state_guess), (2,0))))
    for i in range (np.size(state_guess, 1)):
        xs, ys, vxs, vys = state_guess[:,i]
        xsf = xs
        ysf = ys - 2*ys*math.sin(phi)**2
        zsf = 2*ys*math.sin(phi)*math.cos(phi)
        vxsf = vxs
        vysf = vys - 2*vys*math.sin(phi)**2
        vzsf = 2*vys*math.sin(phi)*math.cos(phi)
        state_guess_3d[:,i] = [xsf, ysf, zsf, vxsf, vysf, vzsf]

    time_guess = guess_sol["time"]

    phase = problem.guess.phase[0]
    phase.time = time_guess
    phase.state = state_guess_3d

    problem.derivatives.method = "auto"
    problem.derivatives.order = "second"
    problem.spectral_method = "lgl"
    segments, points = 100, 10
    problem.mesh.phase[0].collocation_points = segments*[points]
    problem.mesh.phase[0].fraction = segments*[1/segments]

    problem.ipopt_options.mu_strategy = "adaptive"
    problem.ipopt_options.print_level = 3
    problem.ipopt_options.print_user_options = "yes"
    problem.ipopt_options.timing_statistics = "yes"
    problem.ipopt_options.sb = "yes"
    problem.ipopt_options.tol = 1e-8

    solution = problem.solve()
    solve_time = timing.time() - start

    return solve_time, solution

max_time = 30

# %%
C_value = 3.151175879508174
W_v = 1
W_th = 0.001
step = 1
initial = 1
for angle in range(initial, 90, step):

    print("\n Degree Target", angle)

    solve_time, solution = solve_problem(angle)

    state = solution.phase[0].state
    time = solution.phase[0].time
    control = solution.phase[0].control
    time_c = solution.phase[0].time_c
    t0 = solution.phase[0].initial_time
    tf = solution.phase[0].final_time
    x, y, z, vx, vy, vz = state

    print("Solve Time", solve_time)
    print("Orbit Period (nondimensional time)", tf)
    print("Difference in final x position", x[0] - x[-1])
    print("Difference in final y position", y[0] - y[-1])
    print("Difference in final z position", z[0] - z[-1])
    print("Difference in final x velocity", vx[0] - vx[-1])
    print("Difference in final y velocity", vy[0] - vy[-1])
    print("Difference in final z velocity", vz[0] - vz[-1])
    print("Velocity Cross Product", math.cross([vx[0], vy[0], vz[0]], [vx[-1], vy[-1], vz[-1]]))
    def U(x, y, z):
        r1 = math.sqrt((x + mu)**2 + y**2 + z**2)
        r2 = math.sqrt((x - 1 + mu)**2 + y**2 + z**2)
        return -0.5*(x**2 + y**2) - (1 - mu)/r1 - mu/r2

    C_vals = np.zeros((len(x), 1))
    for i in range (len(x)):
        C_vals[i] = -2*U(x[i], y[i], z[i]) - (vx[i]**2 + vy[i]**2 + vz[i]**2)
    C_err = np.ptp(C_vals) # Maximum Jacobi constant deviation
    print("Maximum Jacobi Constant Deviation", C_err)
    hamiltonian = solution.phase[0].hamiltonian
    hamil_dev = np.ptp(hamiltonian)
    print("Maximum Hamiltonian Deviation", hamil_dev)
    print("Angle", math.rad2deg(math.arccos(math.dot([vy[0], vz[0]], [-1, 0])/math.sqrt(vy[0]**2 + vz[0]**2))))

    name = f"z_{angle}"
    np.savez(
        name,
        state = state,
        time = time,
        C_vals = C_vals,
        hamiltonian = hamiltonian
    )
# Out:
#  Degree Target 1
# Solve Time 4.377490520477295
# Orbit Period (nondimensional time) 11.240307549318786
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -1.7742489088709047e-09
# Difference in final y velocity 9.2148511043888e-15
# Difference in final z velocity 2.2053755903286446e-22
# Velocity Cross Product [ 6.61263207e-23 -2.39257019e-32  5.31993520e-10]
# Maximum Jacobi Constant Deviation 1.7252377304544098e-10
# Maximum Hamiltonian Deviation 1.2998648445754978e-10
# Angle 0.0
#
#  Degree Target 2
# Solve Time 4.253487825393677
# Orbit Period (nondimensional time) 10.755413912358717
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -3.023412590556161e-09
# Difference in final y velocity 4.551914400963142e-15
# Difference in final z velocity -1.7419999055216924e-21
# Velocity Cross Product [-4.92159018e-22 -8.93283840e-31  8.54190501e-10]
# Maximum Jacobi Constant Deviation 1.9095258707579887e-10
# Maximum Hamiltonian Deviation 2.178258583135975e-10
# Angle 0.0
#
#  Degree Target 3
# Solve Time 2.2898266315460205
# Orbit Period (nondimensional time) 10.280665526569212
# Difference in final x position 0.0
# Difference in final y position -2.274746684520826e-24
# Difference in final z position 1.5596026615252285e-28
# Difference in final x velocity 2.7274191221099966e-10
# Difference in final y velocity -8.326672684688674e-16
# Difference in final z velocity -1.4814370550228056e-21
# Velocity Cross Product [-3.79265906e-22  2.45439404e-29 -6.98252470e-11]
# Maximum Jacobi Constant Deviation 1.8920376376740933e-10
# Maximum Hamiltonian Deviation 2.484540570309456e-11
# Angle 0.0
#
#  Degree Target 4
# Solve Time 15.649689197540283
# Orbit Period (nondimensional time) 9.737196110558777
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -7.212829761648778e-07
# Difference in final y velocity 1.1691259071966442e-11
# Difference in final z velocity -1.6181614660421242e-19
# Velocity Cross Product [-3.10785391e-20  5.04122733e-25  1.38530188e-07]
# Maximum Jacobi Constant Deviation 4.068705372617387e-10
# Maximum Hamiltonian Deviation 3.530329093713503e-08
# Angle 0.0
#
#  Degree Target 5
# Solve Time 39.603405475616455
# Orbit Period (nondimensional time) 8.612651385219896
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -3.0200297818083754e-10
# Difference in final y velocity 1.3418732791592447e-10
# Difference in final z velocity -4.1434312990484005e-08
# Velocity Cross Product [-6.61551435e-08  2.93891754e-08  5.77364601e-10]
# Maximum Jacobi Constant Deviation 1.425526363618701e-13
# Maximum Hamiltonian Deviation 1.3702176817426345e-09
# Angle 8.537736462515939e-07
#
#  Degree Target 6
# Solve Time 174.21016812324524
# Orbit Period (nondimensional time) 4.108673641147803e-11
# Difference in final x position -3.375077994860476e-14
# Difference in final y position -5.0182080713057076e-14
# Difference in final z position -2.913225216616411e-13
# Difference in final x velocity -5.454166632223867e-11
# Difference in final y velocity -9.13507013089454e-11
# Difference in final z velocity -2.1637205915858715e-14
# Velocity Cross Product [ 4.19345589e-13 -2.50358931e-13 -6.20695444e-14]
# Maximum Jacobi Constant Deviation 9.126921440838487e-12
# Maximum Hamiltonian Deviation 48293077.94376665
# Angle 16.145116103472663
#
#  Degree Target 7
# Solve Time 5.5694286823272705
# Orbit Period (nondimensional time) 10.064408759527241
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 2.4083703229420277e-09
# Difference in final y velocity 3.0531133177191805e-15
# Difference in final z velocity -2.004941060505096e-18
# Velocity Cross Product [-4.77872526e-19  5.28810940e-31 -5.74028849e-10]
# Maximum Jacobi Constant Deviation 1.6555290471842454e-10
# Maximum Hamiltonian Deviation 1.5803337876433305e-10
# Angle 0.0
#
#  Degree Target 8
# Solve Time 5.824094533920288
# Orbit Period (nondimensional time) 9.883170596303785
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -7.908694086021772e-08
# Difference in final y velocity 4.718447854656915e-15
# Difference in final z velocity -2.140785440306768e-16
# Velocity Cross Product [-4.66585852e-17  5.00041168e-29  1.72370603e-08]
# Maximum Jacobi Constant Deviation 2.2567192559108662e-10
# Maximum Hamiltonian Deviation 4.6761163887260575e-09
# Angle 0.0
#
#  Degree Target 9
# Solve Time 5.743032693862915
# Orbit Period (nondimensional time) 9.768086519518521
# Difference in final x position 0.0
# Difference in final y position 6.310887241768094e-29
# Difference in final z position 0.0
# Difference in final x velocity -1.94424109502072e-08
# Difference in final y velocity 1.457167719820518e-14
# Difference in final z velocity -4.159939302134617e-15
# Velocity Cross Product [-8.27806835e-16 -6.97316678e-28  3.86894123e-09]
# Maximum Jacobi Constant Deviation 9.520517707528597e-11
# Maximum Hamiltonian Deviation 1.0056376529200244e-09
# Angle 0.0
#
#  Degree Target 10
# Solve Time 14.641130447387695
# Orbit Period (nondimensional time) 11.18672200335373
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.0521532676296426e-09
# Difference in final y velocity 4.6199155612214327e-14
# Difference in final z velocity -3.913204298283159e-08
# Velocity Cross Product [4.43067666e-09 1.87744521e-13 1.19128739e-10]
# Maximum Jacobi Constant Deviation 8.193445921733655e-13
# Maximum Hamiltonian Deviation 1.4450703171906886e-11
# Angle 179.99999008004667
#
#  Degree Target 11
# Solve Time 335.1531481742859
# Orbit Period (nondimensional time) 2.1634209257994996
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -0.04228905133268279
# Difference in final y velocity 0.06056560017134327
# Difference in final z velocity 254091.6772608718
# Velocity Cross Product [ 6.66679870e+05 -9.54794886e+05  3.38543102e-01]
# Maximum Jacobi Constant Deviation 16163801975.637556
# Maximum Hamiltonian Deviation 9.971387509043698e+22
# Angle 89.99883122074206
#
#  Degree Target 12
# Solve Time 9.164525032043457
# Orbit Period (nondimensional time) 10.787863346640703
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -1.867319293054053e-08
# Difference in final y velocity -1.609823385706477e-15
# Difference in final z velocity 3.35789867225782e-16
# Velocity Cross Product [ 9.53416723e-17 -1.31641184e-23  5.30192723e-09]
# Maximum Jacobi Constant Deviation 1.8991919148447778e-10
# Maximum Hamiltonian Deviation 1.3507648964811715e-09
# Angle 0.0
#
#  Degree Target 13
# Solve Time 234.9081370830536
# Orbit Period (nondimensional time) 352498125469404.6
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -598840536.2146893
# Difference in final y velocity 454294485.555851
# Difference in final z velocity -534066420.0221155
# Velocity Cross Product [ 9.48047340e+18 -7.20206954e+18 -1.67566279e+19]
# Maximum Jacobi Constant Deviation 8.13367255058544e+19
# Maximum Hamiltonian Deviation 0.0
# Angle 179.14905936019053
#
#  Degree Target 14
# Solve Time 7.025457859039307
# Orbit Period (nondimensional time) 9.657285135132916
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -1.160796285574651e-09
# Difference in final y velocity -1.7319479184152442e-14
# Difference in final z velocity -1.7795761905413577e-12
# Velocity Cross Product [-2.71439210e-13  1.83559738e-23  1.77056553e-10]
# Maximum Jacobi Constant Deviation 5.820988135951666e-11
# Maximum Hamiltonian Deviation 3.539374052799783e-11
# Angle 0.0
#
#  Degree Target 15
# Solve Time 464.3314542770386
# Orbit Period (nondimensional time) 6.320077011020544
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -0.580476149695329
# Difference in final y velocity -0.24720326368715462
# Difference in final z velocity 57240.53224735227
# Velocity Cross Product [-1.87066562e+06 -7.96647582e+05 -2.24108793e+01]
# Maximum Jacobi Constant Deviation 819154444.3437265
# Maximum Hamiltonian Deviation 9.537250412884363e+20
# Angle 90.06517858003987
#
#  Degree Target 16
# Solve Time 13.361932754516602
# Orbit Period (nondimensional time) 9.98512065217091
# Difference in final x position 0.0
# Difference in final y position -8.077935669463161e-28
# Difference in final z position 0.0
# Difference in final x velocity 5.4577258450016465e-06
# Difference in final y velocity 4.529709940470639e-14
# Difference in final z velocity 2.3501532976021323e-06
# Velocity Cross Product [ 9.60729326e-08  2.15673048e-16 -2.23108734e-07]
# Maximum Jacobi Constant Deviation 1.4550849414263212e-10
# Maximum Hamiltonian Deviation 1.3419328791951789e-08
# Angle 0.0016469636647483679
#
#  Degree Target 17
# Solve Time 57.338606119155884
# Orbit Period (nondimensional time) 0.6494097126194099
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.01570925423321423
# Difference in final y velocity -0.0015355154460754972
# Difference in final z velocity -1.7655231636180797e-11
# Velocity Cross Product [-3.67578998e-12 -3.76055607e-11 -4.27435864e-15]
# Maximum Jacobi Constant Deviation 44.59757328294471
# Maximum Hamiltonian Deviation 1.5595609425189004e-09
# Angle 0.0
#
#  Degree Target 18
# Solve Time 10.717036247253418
# Orbit Period (nondimensional time) 13.35550065134133
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -2.3766050551592787e-06
# Difference in final y velocity -3.985700658404312e-14
# Difference in final z velocity 4.3010559040755935e-12
# Velocity Cross Product [1.38245310e-12 1.91850639e-20 7.63892658e-07]
# Maximum Jacobi Constant Deviation 7.429670212388828e-10
# Maximum Hamiltonian Deviation 1.422766147296127e-07
# Angle 0.0
#
#  Degree Target 19
# Solve Time 16.02180528640747
# Orbit Period (nondimensional time) 10.00384704893582
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.24774738684355874
# Difference in final y velocity -1.0096557640457303e-08
# Difference in final z velocity 1.1257485165298355e-06
# Velocity Cross Product [-4.48333128e-13 -7.31488236e-14  9.86662283e-08]
# Maximum Jacobi Constant Deviation 4.0511462628955996e-08
# Maximum Hamiltonian Deviation 1.0529963777933062e-08
# Angle 124.93684422254006
#
#  Degree Target 20
# Solve Time 1052.0467495918274
# Orbit Period (nondimensional time) 464.95578842101634
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -6.967457011342049e-08
# Difference in final y velocity -2.2308086045086384e-07
# Difference in final z velocity 3.18317178104126e-11
# Velocity Cross Product [1.80178249e-07 5.77159030e-07 4.43919003e-03]
# Maximum Jacobi Constant Deviation 0.0002480149269104004
# Maximum Hamiltonian Deviation 6.708817090728125e-05
# Angle 0.0
#
#  Degree Target 21
# Solve Time 124.0216429233551
# Orbit Period (nondimensional time) 11.396382735962712
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.7097328162943266
# Difference in final y velocity 0.17875898918277158
# Difference in final z velocity 0.2629628430968605
# Velocity Cross Product [-0.05807305 -0.0599831   0.19751409]
# Maximum Jacobi Constant Deviation 1.8761326545794006
# Maximum Hamiltonian Deviation 9.558959478363592
# Angle 146.94700714090717
#
#  Degree Target 22
# Solve Time 626.3590090274811
# Orbit Period (nondimensional time) 164.53473456959983
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.5060098117556393
# Difference in final y velocity 0.6722707082529045
# Difference in final z velocity 9.865857521853172e-07
# Velocity Cross Product [-1.39463421e-05 -1.85287259e-05  1.97786209e+01]
# Maximum Jacobi Constant Deviation 432.08664477834054
# Maximum Hamiltonian Deviation 27566.673446898647
# Angle 179.9999979086902
#
#  Degree Target 23
# Solve Time 248.6927843093872
# Orbit Period (nondimensional time) 5.933992370112492
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -0.04394926287728396
# Difference in final y velocity 0.30631159406334163
# Difference in final z velocity 6287.560246682685
# Velocity Cross Product [-4.87581853e+04  3.39828054e+05 -1.68962451e+01]
# Maximum Jacobi Constant Deviation 9883504.601012232
# Maximum Hamiltonian Deviation 1.3716099693249823e+19
# Angle 90.14412376642336
#
#  Degree Target 24
# Solve Time 251.82827711105347
# Orbit Period (nondimensional time) 1.2809177403280643
# Difference in final x position 1.1102230246251565e-16
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.02523730329071916
# Difference in final y velocity -0.03931407686711719
# Difference in final z velocity 235792.93330284068
# Velocity Cross Product [-2.31667634e+05  3.60810571e+05  8.49542036e-02]
# Maximum Jacobi Constant Deviation 14136938538.447966
# Maximum Hamiltonian Deviation 1.989296880908838e+23
# Angle 90.00046390288222
#
#  Degree Target 25
# Solve Time 21.99967050552368
# Orbit Period (nondimensional time) 8.399456642997407
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.0028105604666811487
# Difference in final y velocity -3.819891712891765e-05
# Difference in final z velocity -9.040761692244437e-05
# Velocity Cross Product [-1.50966405e-05 -1.86741644e-04 -3.90417242e-04]
# Maximum Jacobi Constant Deviation 0.001401636014237262
# Maximum Hamiltonian Deviation 2.8501111270637388e-05
# Angle 25.581848575597224
#
#  Degree Target 26
# Solve Time 8.283876657485962
# Orbit Period (nondimensional time) 10.005873541576081
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.256200430272359
# Difference in final y velocity 3.919459358764664e-11
# Difference in final z velocity -7.146283279365102e-09
# Velocity Cross Product [ 3.42021122e-16 -1.75036489e-18  1.22617527e-08]
# Maximum Jacobi Constant Deviation 4.6151639399028e-08
# Maximum Hamiltonian Deviation 1.3835385439623027e-09
# Angle 175.7320622925399
#
#  Degree Target 27
# Solve Time 10.83577275276184
# Orbit Period (nondimensional time) -1.0608950133942559e-13
# Difference in final x position 0.0
# Difference in final y position -2.752857078576476e-21
# Difference in final z position 4.7539724164647607e-20
# Difference in final x velocity -3.8993519720032917e-13
# Difference in final y velocity -6.979551485375435e-19
# Difference in final z velocity -6.2341624917916505e-19
# Velocity Cross Product [-5.52143059e-23  1.35744102e-17  1.93411425e-17]
# Maximum Jacobi Constant Deviation 1.2434497875801753e-14
# Maximum Hamiltonian Deviation 15531244.886343908
# Angle 35.06275948699364
#
#  Degree Target 28
# Solve Time 55.858542680740356
# Orbit Period (nondimensional time) 18.925140532830632
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.0022469414714343383
# Difference in final y velocity 0.027002252702051255
# Difference in final z velocity -0.027601973651431688
# Velocity Cross Product [-0.00614376 -0.01300015 -0.01321782]
# Maximum Jacobi Constant Deviation 1.0802121219942613
# Maximum Hamiltonian Deviation 0.8508197530407244
# Angle 131.40161640815228
#
#  Degree Target 29
# Solve Time 17.806166410446167
# Orbit Period (nondimensional time) 4.162694719482556
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.3100779660577104
# Difference in final y velocity 0.013583078657300834
# Difference in final z velocity -8.101299997602724e-05
# Velocity Cross Product [-5.44601027e-08  5.25286369e-06  3.80212174e-08]
# Maximum Jacobi Constant Deviation 7.048295280753791e-10
# Maximum Hamiltonian Deviation 1.080325145306764e-07
# Angle 179.62445389599674
#
#  Degree Target 30
# Solve Time 37.02051830291748
# Orbit Period (nondimensional time) 5.267134415994695
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.5892294964281979
# Difference in final y velocity -0.2806580722287274
# Difference in final z velocity -1.1080020569985977e-08
# Velocity Cross Product [1.40818273e-09 2.95641880e-09 3.79587334e-12]
# Maximum Jacobi Constant Deviation 2.9702311117318914e-06
# Maximum Hamiltonian Deviation 4.1817195076393503e-11
# Angle 4.26886823125797e-06
#
#  Degree Target 31
# Solve Time 20.756077527999878
# Orbit Period (nondimensional time) 10.582190407033828
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.1162020700708851
# Difference in final y velocity 0.0015142370424918612
# Difference in final z velocity -0.3709597978486349
# Velocity Cross Product [-4.78136977e-05 -2.87359220e-05 -1.50947992e-05]
# Maximum Jacobi Constant Deviation 0.0858578958552898
# Maximum Hamiltonian Deviation 0.01576414393349619
# Angle 90.19390189973001
#
#  Degree Target 32
# Solve Time 139.27926588058472
# Orbit Period (nondimensional time) 6.18784386787604
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.014970883070724028
# Difference in final y velocity 0.006179350794699445
# Difference in final z velocity -281.4353115105652
# Velocity Cross Product [-7.17377799e+03 -2.96113211e+03 -4.46623648e-01]
# Maximum Jacobi Constant Deviation 19769.143918623144
# Maximum Hamiltonian Deviation 3.714988656243507e+16
# Angle 79.73380744556464
#
#  Degree Target 33
# Solve Time 12.196331262588501
# Orbit Period (nondimensional time) 4.11573115359495
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -4.543015721501114e-07
# Difference in final y velocity 1.9496293468534986e-10
# Difference in final z velocity 6.727837338613181e-14
# Velocity Cross Product [ 5.80453734e-14 -2.49093064e-17  3.91955214e-07]
# Maximum Jacobi Constant Deviation 2.1463364419105346e-10
# Maximum Hamiltonian Deviation 3.976815648246707e-07
# Angle 0.0
#
#  Degree Target 34
# Solve Time 526.3064827919006
# Orbit Period (nondimensional time) 719.4213478882228
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -0.155258686806782
# Difference in final y velocity 0.1752378745859957
# Difference in final z velocity -1.1212361709064067e-06
# Velocity Cross Product [-3.52401483e-05  3.97749640e-05  1.10961630e+01]
# Maximum Jacobi Constant Deviation 0.1312135112639794
# Maximum Hamiltonian Deviation 16.888945239943904
# Angle 8.537736462515939e-07
#
#  Degree Target 35
# Solve Time 12.596530675888062
# Orbit Period (nondimensional time) 3.0859659640260464
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.497617534323624
# Difference in final y velocity -1.745705562198793e-05
# Difference in final z velocity -1.0180818003954035e-06
# Velocity Cross Product [-1.94122558e-14 -1.48974624e-11 -2.83003476e-08]
# Maximum Jacobi Constant Deviation 19.84098970453241
# Maximum Hamiltonian Deviation 3.363606752402541e-06
# Angle 3.3304054369925282
#
#  Degree Target 36
# Solve Time 835.473875284195
# Orbit Period (nondimensional time) 747.6994979210189
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -2.4518976715626195e-07
# Difference in final y velocity 1.5448495105374604e-07
# Difference in final z velocity -5.156800671310856e-11
# Velocity Cross Product [-5.47731395e-07  3.45068249e-07  3.63802910e-03]
# Maximum Jacobi Constant Deviation 0.02010446786880493
# Maximum Hamiltonian Deviation 0.0008455179813614544
# Angle 0.0
#
#  Degree Target 37
# Solve Time 11.104098081588745
# Orbit Period (nondimensional time) 5.227055409530974
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.230520368865099
# Difference in final y velocity 1.5264435104115341e-06
# Difference in final z velocity 1.9063815137798597e-06
# Velocity Cross Product [-2.05284779e-15  1.09399441e-12  1.32418463e-09]
# Maximum Jacobi Constant Deviation 3.9158625275703685e-07
# Maximum Hamiltonian Deviation 2.77702282935085e-09
# Angle 128.72374495283506
#
#  Degree Target 38
# Solve Time 103.53802037239075
# Orbit Period (nondimensional time) 12.735823361732079
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.1236753988185948
# Difference in final y velocity -0.9312579318174405
# Difference in final z velocity 0.39719900907952876
# Velocity Cross Product [-1.87625183e-05 -4.46861293e-05 -9.89273626e-05]
# Maximum Jacobi Constant Deviation 52.365604898609455
# Maximum Hamiltonian Deviation 1.2434616084751662
# Angle 156.90099469255134
#
#  Degree Target 39
# Solve Time 11.824183702468872
# Orbit Period (nondimensional time) 2.5535833221913082e-15
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -3.6830734046356534e-14
# Difference in final y velocity -2.1163626406917047e-16
# Difference in final z velocity -2.6320091939258106e-15
# Velocity Cross Product [-1.00093883e-17 -1.16987674e-17  1.41005760e-16]
# Maximum Jacobi Constant Deviation 1.687538997430238e-14
# Maximum Hamiltonian Deviation 101.69751256151439
# Angle 4.697398366428497
#
#  Degree Target 40
# Solve Time 9.94966173171997
# Orbit Period (nondimensional time) 3.8264559693396416
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.1840998652831565
# Difference in final y velocity 1.932135447002885e-05
# Difference in final z velocity 1.2963984299151612e-07
# Velocity Cross Product [-4.62494019e-18 -8.80378782e-12  1.35434826e-09]
# Maximum Jacobi Constant Deviation 7.911072641419992e-08
# Maximum Hamiltonian Deviation 2.883704328112875e-09
# Angle 179.61557162135603
#
#  Degree Target 41
# Solve Time 761.6929426193237
# Orbit Period (nondimensional time) 2301.468478465165
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 3.7062545743538067e-07
# Difference in final y velocity 2.6377801987109706e-07
# Difference in final z velocity -6.697447839050467e-10
# Velocity Cross Product [3.17582672e-06 2.26008355e-06 2.64757872e-03]
# Maximum Jacobi Constant Deviation 14.801791984587908
# Maximum Hamiltonian Deviation 0.13164596672686543
# Angle 180.0
#
#  Degree Target 42
# Solve Time 8.162231683731079
# Orbit Period (nondimensional time) 4.179005463013156
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.3183007102336142
# Difference in final y velocity -7.884834134510739e-11
# Difference in final z velocity 1.601855348954973e-09
# Velocity Cross Product [ 3.45819833e-17  6.28543425e-19 -2.84604057e-08]
# Maximum Jacobi Constant Deviation 4.8552273312907346e-11
# Maximum Hamiltonian Deviation 7.722986506893076e-08
# Angle 2.1207943774482043
#
#  Degree Target 43
# Solve Time 87.1686749458313
# Orbit Period (nondimensional time) 12.190387402653796
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.004322258693435221
# Difference in final y velocity 0.004940873183890998
# Difference in final z velocity -0.0006886184167756992
# Velocity Cross Product [-0.00198489  0.00203189  0.00212037]
# Maximum Jacobi Constant Deviation 3.230095506623343e-07
# Maximum Hamiltonian Deviation 1.3891547705021019e-08
# Angle 113.02027074191341
#
#  Degree Target 44
# Solve Time 22.126999855041504
# Orbit Period (nondimensional time) -2.3300276401559177e-15
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -6.772360450213455e-15
# Difference in final y velocity -6.661338147750939e-16
# Difference in final z velocity 3.6637359812630166e-15
# Velocity Cross Product [5.10702591e-15 4.60742555e-15 1.03250741e-14]
# Maximum Jacobi Constant Deviation 1.509903313490213e-14
# Maximum Hamiltonian Deviation 9.652939926798091e-05
# Angle 28.746621208586525
#
#  Degree Target 45
# Solve Time 11.845546245574951
# Orbit Period (nondimensional time) 11.762229071371546
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.0657195727899887e-08
# Difference in final y velocity 1.382412813805134e-06
# Difference in final z velocity -4.080979240158747e-11
# Velocity Cross Product [ 5.60731877e-12 -4.91708627e-14 -2.01327586e-10]
# Maximum Jacobi Constant Deviation 0.00016045141843212818
# Maximum Hamiltonian Deviation 1.6802205033285046e-08
# Angle 180.0
#
#  Degree Target 46
# Solve Time 141.2116982936859
# Orbit Period (nondimensional time) 18.9176667877746
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.0014821792539930767
# Difference in final y velocity -0.014602087213004045
# Difference in final z velocity 0.02916951980989091
# Velocity Cross Product [ 0.01400735 -0.01650401 -0.00897356]
# Maximum Jacobi Constant Deviation 0.5084759447671718
# Maximum Hamiltonian Deviation 0.5559801217696789
# Angle 101.11160228290701
#
#  Degree Target 47
# Solve Time 139.6064932346344
# Orbit Period (nondimensional time) 34.530984148347535
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -4.258411056894985
# Difference in final y velocity 4.669799328067874
# Difference in final z velocity 3.080898358966152
# Velocity Cross Product [-1.02926529e-03 -9.35957362e-04 -3.99287862e-06]
# Maximum Jacobi Constant Deviation 4.284249889328585
# Maximum Hamiltonian Deviation 1.1466735009653886
# Angle 146.58897526364854
#
#  Degree Target 48
# Solve Time 165.3131184577942
# Orbit Period (nondimensional time) 1140482.4947607666
# Difference in final x position 0.0
# Difference in final y position -3.637978807091713e-12
# Difference in final z position 0.0
# Difference in final x velocity 13.628325030676933
# Difference in final y velocity 48.647403397196285
# Difference in final z velocity 2.6356130254461754e-07
# Velocity Cross Product [ 2.01175227e-03  4.35109872e-03 -9.07137983e+05]
# Maximum Jacobi Constant Deviation 61157655.24146056
# Maximum Hamiltonian Deviation 784957.1687011719
# Angle 0.0
#
#  Degree Target 49
# Solve Time 6.784313440322876
# Orbit Period (nondimensional time) 4.269900505541381
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.3759079045490727
# Difference in final y velocity -2.356989885426316e-11
# Difference in final z velocity 1.3430239357981775e-10
# Velocity Cross Product [-1.40079586e-18  2.79532634e-20  1.43509438e-08]
# Maximum Jacobi Constant Deviation 2.2243540342969936e-11
# Maximum Hamiltonian Deviation 4.184950773985268e-08
# Angle 179.63070769329764
#
#  Degree Target 50
# Solve Time 142.2011034488678
# Orbit Period (nondimensional time) 100.35991809583832
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -1.1363774541649632
# Difference in final y velocity -0.8451276907711753
# Difference in final z velocity -17.906349463853296
# Velocity Cross Product [-0.04861032  0.12058514 -0.00260635]
# Maximum Jacobi Constant Deviation 81.30537336661826
# Maximum Hamiltonian Deviation 13.145472774622045
# Angle 87.28058366155258
#
#  Degree Target 51
# Solve Time 73.60905861854553
# Orbit Period (nondimensional time) -5.685159932092982e-15
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -1.0130785099704553e-14
# Difference in final y velocity -8.548717289613705e-15
# Difference in final z velocity -3.7470027081099033e-16
# Velocity Cross Product [ 5.75928194e-16 -1.01828268e-15  7.64666108e-15]
# Maximum Jacobi Constant Deviation 9.103828801926284e-15
# Maximum Hamiltonian Deviation 1.1251732878747589e-10
# Angle 8.436849700545766
#
#  Degree Target 52
# Solve Time 187.77692985534668
# Orbit Period (nondimensional time) 8.850947663966508
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -98.22468918277127
# Difference in final y velocity 5.41851621893511
# Difference in final z velocity 4746622.360681978
# Velocity Cross Product [ 1.47444688e+11 -8.13371156e+09  3.06044596e+06]
# Maximum Jacobi Constant Deviation 5632688419075.691
# Maximum Hamiltonian Deviation 7.528356064153826e+24
# Angle 89.2501980925407
#
#  Degree Target 53
# Solve Time 7.441816568374634
# Orbit Period (nondimensional time) 7.420795527887994
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -6.275430956131922e-10
# Difference in final y velocity 3.0108415760565777e-11
# Difference in final z velocity 1.3467084810004074e-22
# Velocity Cross Product [ 2.21877658e-23 -1.06450599e-24  1.03629182e-10]
# Maximum Jacobi Constant Deviation 4.3653969328261155e-13
# Maximum Hamiltonian Deviation 2.0350929620890075e-11
# Angle 0.0
#
#  Degree Target 54
# Solve Time 10.8994300365448
# Orbit Period (nondimensional time) 6.265847155148652
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 3.447357355232904e-05
# Difference in final y velocity -4.4833363932461623e-07
# Difference in final z velocity 3.3350768369189154e-07
# Velocity Cross Product [ 8.42960376e-07  3.52755866e-05 -3.97131013e-05]
# Maximum Jacobi Constant Deviation 1.3705205681446841e-07
# Maximum Hamiltonian Deviation 1.6192654884293398e-08
# Angle 41.616414593813616
#
#  Degree Target 55
# Solve Time 11.504854679107666
# Orbit Period (nondimensional time) 4.273458666932205
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.378360388204794
# Difference in final y velocity 2.4677841727774865e-06
# Difference in final z velocity 2.7559807009036633e-06
# Velocity Cross Product [-9.88936180e-14 -6.29117753e-11  4.95164202e-08]
# Maximum Jacobi Constant Deviation 2.0440271697452772e-10
# Maximum Hamiltonian Deviation 1.4456840200200996e-07
# Angle 132.65957993413338
#
#  Degree Target 56
# Solve Time 203.99471163749695
# Orbit Period (nondimensional time) -626.579142290949
# Difference in final x position 8.367496775463223e-07
# Difference in final y position 9.117648005485535e-07
# Difference in final z position -8589934592.0
# Difference in final x velocity -103.7992791850993
# Difference in final y velocity 197.49531287627178
# Difference in final z velocity 65233458.5117418
# Velocity Cross Product [ 7.74724542e+12 -1.18100586e+13  4.80825297e+07]
# Maximum Jacobi Constant Deviation 4.7353397325165144e+16
# Maximum Hamiltonian Deviation 1.602310358688482e+33
# Angle 89.93614453950279
#
#  Degree Target 57
# Solve Time 25.39392113685608
# Orbit Period (nondimensional time) 10.129966165598283
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.06573733113801492
# Difference in final y velocity -0.03490284904484517
# Difference in final z velocity -0.0534705256124183
# Velocity Cross Product [-0.00069236 -0.00098106 -0.00021081]
# Maximum Jacobi Constant Deviation 0.7085489502782414
# Maximum Hamiltonian Deviation 0.003895013961505011
# Angle 54.30464205945312
#
#  Degree Target 58
# Solve Time 117.36811971664429
# Orbit Period (nondimensional time) 37.6507992109734
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.038728295479459385
# Difference in final y velocity -0.044190737894980625
# Difference in final z velocity 0.04980537139714625
# Velocity Cross Product [ 0.00693435 -0.04667781 -0.04680785]
# Maximum Jacobi Constant Deviation 1.3830594638259424
# Maximum Hamiltonian Deviation 1.8388176466382555
# Angle 46.04354207555588
#
#  Degree Target 59
# Solve Time 86.40508031845093
# Orbit Period (nondimensional time) 7.64215593596225e-12
# Difference in final x position 1.1391421139705926e-10
# Difference in final y position 6.366462912410498e-12
# Difference in final z position 1.6007106751203537e-10
# Difference in final x velocity 4.07476175023902e-09
# Difference in final y velocity -9.22968723671147e-09
# Difference in final z velocity -1.3072876114961218e-14
# Velocity Cross Product [-9.04753605e-10 -3.99545647e-10  7.84687071e-08]
# Maximum Jacobi Constant Deviation 1.193024218082428e-06
# Maximum Hamiltonian Deviation 47844711621.70438
# Angle 179.67618595700316
#
#  Degree Target 60
# Solve Time 88.67862677574158
# Orbit Period (nondimensional time) 5175.175034638329
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 12.0
# Difference in final x velocity 152300071979.79276
# Difference in final y velocity -783331333993.0046
# Difference in final z velocity 2.7939677238464355e-08
# Velocity Cross Product [8.60694314e+18 1.67341456e+18 4.31095719e+19]
# Maximum Jacobi Constant Deviation 9.840294570769751e+22
# Maximum Hamiltonian Deviation 1.0628458606524995e+29
# Angle 0.0016073925490834055
#
#  Degree Target 61
# Solve Time 14.345087051391602
# Orbit Period (nondimensional time) 8.399515579499633
# Difference in final x position 0.0
# Difference in final y position 3.3881317890172014e-21
# Difference in final z position 0.0
# Difference in final x velocity 0.0028151538306909283
# Difference in final y velocity 1.3118739173589855e-06
# Difference in final z velocity 2.6775343200807766e-06
# Velocity Cross Product [ 4.59050695e-07 -1.87323238e-04 -3.90864776e-04]
# Maximum Jacobi Constant Deviation 0.0005438460888247398
# Maximum Hamiltonian Deviation 3.3233613520175673e-06
# Angle 25.606814529197276
#
#  Degree Target 62
# Solve Time 80.94693088531494
# Orbit Period (nondimensional time) -17.894062596338102
# Difference in final x position -8.391296546506055e-10
# Difference in final y position -4.3525894000140397e-10
# Difference in final z position 0.0
# Difference in final x velocity -0.38133461908958743
# Difference in final y velocity 0.8150972167433892
# Difference in final z velocity 5814180.334727934
# Velocity Cross Product [-3.90647816e+07  8.04815198e+07 -1.38449466e+01]
# Maximum Jacobi Constant Deviation 8525301008648.253
# Maximum Hamiltonian Deviation 3.264099712959499e+26
# Angle 90.00014103667577
#
#  Degree Target 63
# Solve Time 36.16651225090027
# Orbit Period (nondimensional time) 18.568580931557616
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.11728586825595455
# Difference in final y velocity -0.2429901793499445
# Difference in final z velocity -5.728902860290164e-10
# Velocity Cross Product [-2.84052973e-09 -1.37105951e-09 -1.52766688e-12]
# Maximum Jacobi Constant Deviation 18.349538931762385
# Maximum Hamiltonian Deviation 5.297123609015958e-09
# Angle 0.0
#
#  Degree Target 64
# Solve Time 9.818681955337524
# Orbit Period (nondimensional time) -9.923025730761551e-18
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position -1.5183065579533334e-19
# Difference in final x velocity -1.4432899320127035e-15
# Difference in final y velocity -8.881784197001252e-16
# Difference in final z velocity 1.3322676295501878e-15
# Velocity Cross Product [-7.10542736e-15 -1.77635684e-15 -8.21565038e-15]
# Maximum Jacobi Constant Deviation 1.5631940186722204e-13
# Maximum Hamiltonian Deviation 2.7916148276999593
# Angle 166.09015265249147
#
#  Degree Target 65
# Solve Time 32.37456393241882
# Orbit Period (nondimensional time) 10.811259581654419
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.00015004697271331358
# Difference in final y velocity 0.0008957847913579134
# Difference in final z velocity -0.0005686869506396353
# Velocity Cross Product [ 0.00014687 -0.00013698 -0.00017702]
# Maximum Jacobi Constant Deviation 8.270051310432791e-11
# Maximum Hamiltonian Deviation 7.811489800932137e-11
# Angle 110.73921438885505
#
#  Degree Target 66
# Solve Time 83.41932773590088
# Orbit Period (nondimensional time) 3.009009288888251
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.6193759718574938
# Difference in final y velocity 1.3199242574207801
# Difference in final z velocity 348.5070719444334
# Velocity Cross Product [316063.47513911 257617.77787647  -2444.31639975]
# Maximum Jacobi Constant Deviation 31263.782908635447
# Maximum Hamiltonian Deviation 1.2086271617164902e+17
# Angle 10.881339114015564
#
#  Degree Target 67
# Solve Time 23.182892560958862
# Orbit Period (nondimensional time) 12.532803183576487
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 7.543795336567224e-05
# Difference in final y velocity 0.0005979570873915208
# Difference in final z velocity 0.00032126279642785693
# Velocity Cross Product [ 1.22356514e-06 -4.11754398e-05  7.63513331e-05]
# Maximum Jacobi Constant Deviation 0.011445482235572957
# Maximum Hamiltonian Deviation 0.0003703732624659818
# Angle 151.67479577349354
#
#  Degree Target 68
# Solve Time 29.490354537963867
# Orbit Period (nondimensional time) 3.4790410128313855e-18
# Difference in final x position -3.6637359812630166e-15
# Difference in final y position -1.3552527156068805e-20
# Difference in final z position -1.9651164376299768e-19
# Difference in final x velocity -1.8862259065050794e-17
# Difference in final y velocity -1.4988010832439613e-15
# Difference in final z velocity -1.1823875212257917e-14
# Velocity Cross Product [-1.93595140e-15 -4.17036672e-18  3.61953060e-18]
# Maximum Jacobi Constant Deviation 4.0247805088711175e-12
# Maximum Hamiltonian Deviation 21.97620734224617
# Angle 49.0880784906411
#
#  Degree Target 69
# Solve Time 11.601966857910156
# Orbit Period (nondimensional time) 4.5822204244730775
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.6719757504072346
# Difference in final y velocity -1.9265686569305178e-05
# Difference in final z velocity -2.2734141101956057e-05
# Velocity Cross Product [-5.02164511e-12  2.39086062e-10 -3.69518029e-07]
# Maximum Jacobi Constant Deviation 3.892781208492124e-09
# Maximum Hamiltonian Deviation 1.4383366562104689e-06
# Angle 49.079097728318935
#
#  Degree Target 70
# Solve Time 21.471359729766846
# Orbit Period (nondimensional time) 1.8499933278882124e-15
# Difference in final x position 0.0
# Difference in final y position -7.938604539904116e-18
# Difference in final z position 0.0
# Difference in final x velocity 6.393937128820987e-10
# Difference in final y velocity 6.308287225920139e-13
# Difference in final z velocity 7.956823134397384e-13
# Velocity Cross Product [ 3.39693659e-13 -1.10414943e-12 -2.72095361e-10]
# Maximum Jacobi Constant Deviation 2.205524651799351e-11
# Maximum Hamiltonian Deviation 4485811334513608.0
# Angle 0.232500783066198
#
#  Degree Target 71
# Solve Time 27.526176691055298
# Orbit Period (nondimensional time) 6.380826671335807
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.0021479402013279136
# Difference in final y velocity 0.0006961532215932903
# Difference in final z velocity 0.005737130108644184
# Velocity Cross Product [ 0.00112625 -0.00094079 -0.0003075 ]
# Maximum Jacobi Constant Deviation 0.712595815299796
# Maximum Hamiltonian Deviation 0.14583453822009712
# Angle 88.5385587124663
#
#  Degree Target 72
# Solve Time 108.15739560127258
# Orbit Period (nondimensional time) 12.748920675080235
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.043891685814057585
# Difference in final y velocity 0.035363841332024026
# Difference in final z velocity -0.00445852260015768
# Velocity Cross Product [ 0.00260912 -0.006272   -0.02406248]
# Maximum Jacobi Constant Deviation 7.482566878915257
# Maximum Hamiltonian Deviation 0.3594250944107862
# Angle 17.782742770984513
#
#  Degree Target 73
# Solve Time 281.2567901611328
# Orbit Period (nondimensional time) -4.189058193398979e-15
# Difference in final x position -3.0276222784050844e-08
# Difference in final y position 3.870071030985824e-08
# Difference in final z position 2.8205077462565134e-08
# Difference in final x velocity -5.481523475867112
# Difference in final y velocity -0.38048507809262766
# Difference in final z velocity 1.7101282729400915
# Velocity Cross Product [2.13514655 9.54537888 8.96759057]
# Maximum Jacobi Constant Deviation 379012797.19098943
# Maximum Hamiltonian Deviation 2.0599556911755347e+29
# Angle 53.41436317146243
#
#  Degree Target 74
# Solve Time 10.36432147026062
# Orbit Period (nondimensional time) 3.643771890733977
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.1980112855692964
# Difference in final y velocity -2.6936213162902954e-08
# Difference in final z velocity 4.2632625397216045e-10
# Velocity Cross Product [ 3.54844294e-20  2.68330432e-17 -9.97124238e-11]
# Maximum Jacobi Constant Deviation 0.0001437130849213375
# Maximum Hamiltonian Deviation 2.1952727893541307e-10
# Angle 0.9011906331919581
#
#  Degree Target 75
# Solve Time 98.47434878349304
# Orbit Period (nondimensional time) -1.0665432139043416e-15
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -2.4158453015843406e-13
# Difference in final y velocity -1.4210854715202004e-14
# Difference in final z velocity -1.3552527156068805e-20
# Velocity Cross Product [ 0.00000000e+00 -2.08166817e-17  1.90993887e-11]
# Maximum Jacobi Constant Deviation 6.548361852765083e-11
# Maximum Hamiltonian Deviation 16.76713509340334
# Angle 6.053369549286547e-05
#
#  Degree Target 76
# Solve Time 58.89019799232483
# Orbit Period (nondimensional time) 1.2481094168286795e-05
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.004142773311251875
# Difference in final y velocity -0.00014388202024885242
# Difference in final z velocity 0.0015879606192007723
# Velocity Cross Product [-1.36841480e-11  4.99112845e-13  3.57453050e-11]
# Maximum Jacobi Constant Deviation 8.526512829121202e-14
# Maximum Hamiltonian Deviation 3.8236132233968785e-06
# Angle 84.82329516265975
#
#  Degree Target 77
# Solve Time 57.813377380371094
# Orbit Period (nondimensional time) -6.6958659624687e-17
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position -8.271806125530277e-25
# Difference in final x velocity -1.887379141862766e-15
# Difference in final y velocity -7.494005416219807e-16
# Difference in final z velocity 0.0
# Velocity Cross Product [ 7.11375327e-23 -1.81979735e-22 -4.57966998e-16]
# Maximum Jacobi Constant Deviation 3.197442310920451e-14
# Maximum Hamiltonian Deviation 2801797240.163701
# Angle 179.99995820867392
#
#  Degree Target 78
# Solve Time 49.237303733825684
# Orbit Period (nondimensional time) 6.256477132363466
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 2.241540286718191e-13
# Difference in final y velocity -1.0658141036401503e-13
# Difference in final z velocity 4.024437780781207e-12
# Velocity Cross Product [ 8.14612569e-12 -2.61845506e-13 -4.60659288e-13]
# Maximum Jacobi Constant Deviation 1.156355011744381e-10
# Maximum Hamiltonian Deviation 3.4890768034669095e-12
# Angle 0.0
#
#  Degree Target 79
# Solve Time 107.14576983451843
# Orbit Period (nondimensional time) 0.5560818283937721
# Difference in final x position 0.0
# Difference in final y position -1.1102230246251565e-16
# Difference in final z position 0.0
# Difference in final x velocity -0.12716013415594485
# Difference in final y velocity 0.011238573190027523
# Difference in final z velocity 78359.70921305427
# Velocity Cross Product [-6.27574516e+05  5.54321267e+04 -1.02636212e+00]
# Maximum Jacobi Constant Deviation 1550662824.695761
# Maximum Hamiltonian Deviation 9.208614641595808e+22
# Angle 90.011779921438
#
#  Degree Target 80
# Solve Time 12.466896772384644
# Orbit Period (nondimensional time) 4.64404304549946
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.7555344328166362
# Difference in final y velocity -2.9617034416070906e-10
# Difference in final z velocity 3.133079091988902e-10
# Velocity Cross Product [ 6.56590314e-19 -3.02258517e-20 -3.67902268e-09]
# Maximum Jacobi Constant Deviation 1.4432719908086256e-08
# Maximum Hamiltonian Deviation 1.5558037661131822e-08
# Angle 3.993780144580314
#
#  Degree Target 81
# Solve Time 86.05380153656006
# Orbit Period (nondimensional time) 1.5016383516282303
# Difference in final x position 0.0
# Difference in final y position 8.673617379884035e-19
# Difference in final z position 0.0
# Difference in final x velocity 0.0011824255041517117
# Difference in final y velocity 1.6151131640995686e-05
# Difference in final z velocity 766755.1354986037
# Velocity Cross Product [-8.27933551e+06 -5.19121915e+03  1.27678066e-02]
# Maximum Jacobi Constant Deviation 147332032580.02466
# Maximum Hamiltonian Deviation 2.1345096502570796e+24
# Angle 90.00161568837244
#
#  Degree Target 82
# Solve Time 131.30522465705872
# Orbit Period (nondimensional time) 12.561026834326867
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.08104215526524428
# Difference in final y velocity 0.06562420305184657
# Difference in final z velocity 0.07143220036406417
# Velocity Cross Product [ 1.62969306e-04 -1.63734898e-04 -3.44720114e-05]
# Maximum Jacobi Constant Deviation 11.444755443868207
# Maximum Hamiltonian Deviation 0.5583736239619493
# Angle 132.54368369307767
#
#  Degree Target 83
# Solve Time 192.47283673286438
# Orbit Period (nondimensional time) 2.223246706748796
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -1.9806009850285045
# Difference in final y velocity 0.22844974161937515
# Difference in final z velocity -2802550.6452070596
# Velocity Cross Product [-4.47892975e+07  5.16793681e+06  3.20744750e+01]
# Maximum Jacobi Constant Deviation 1965728897051.948
# Maximum Hamiltonian Deviation 1.4292242160404981e+25
# Angle 89.9993508501303
#
#  Degree Target 84
# Solve Time 46.6205370426178
# Orbit Period (nondimensional time) 15.75449043875175
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -7.017328940150946e-10
# Difference in final y velocity 8.421001673752926e-10
# Difference in final z velocity -6.3221005934166326e-09
# Velocity Cross Product [-1.43342929e-08  1.72015337e-08  3.88229449e-09]
# Maximum Jacobi Constant Deviation 8.171241461241152e-14
# Maximum Hamiltonian Deviation 3.287758322795546e-08
# Angle 0.0
#
#  Degree Target 85
# Solve Time 72.50252509117126
# Orbit Period (nondimensional time) 10.811259581649672
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.00015004697551393442
# Difference in final y velocity 0.0008957847885946307
# Difference in final z velocity -0.0005686869489678337
# Velocity Cross Product [ 0.00014687 -0.00013698 -0.00017702]
# Maximum Jacobi Constant Deviation 8.275602425555917e-11
# Maximum Hamiltonian Deviation 7.812778488208331e-11
# Angle 110.73921405274653
#
#  Degree Target 86
# Solve Time 33.24604415893555
# Orbit Period (nondimensional time) 8.659610361430332
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 1.1269152278003958e-10
# Difference in final y velocity -1.968628871029665e-10
# Difference in final z velocity 3.375077570101018e-24
# Velocity Cross Product [ 7.05292244e-25 -1.23303329e-24 -9.54700902e-11]
# Maximum Jacobi Constant Deviation 3.0464519795714295e-13
# Maximum Hamiltonian Deviation 1.4298011754639697e-11
# Angle 0.0
#
#  Degree Target 87
# Solve Time 33.00474953651428
# Orbit Period (nondimensional time) 8.036494436490457
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 7.225940163065048e-10
# Difference in final y velocity -3.490541189421492e-13
# Difference in final z velocity -4.311310890862343e-07
# Velocity Cross Product [ 9.30547907e-07 -4.64501850e-10  1.55963819e-09]
# Maximum Jacobi Constant Deviation 1.1718626069523452e-11
# Maximum Hamiltonian Deviation 1.6098531878629559e-09
# Angle 179.99999433670632
#
#  Degree Target 88
# Solve Time 66.18608331680298
# Orbit Period (nondimensional time) 12.741658634672573
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity 0.006105423135071453
# Difference in final y velocity -0.05230057267373622
# Difference in final z velocity 0.06623870478125982
# Velocity Cross Product [-0.00021324  0.00111894  0.00090314]
# Maximum Jacobi Constant Deviation 8.843144403317886
# Maximum Hamiltonian Deviation 0.60493764660638
# Angle 128.33166192936045
#
#  Degree Target 89
# Solve Time 11.218295097351074
# Orbit Period (nondimensional time) 12.373375849744653
# Difference in final x position 0.0
# Difference in final y position 0.0
# Difference in final z position 0.0
# Difference in final x velocity -2.6948634725922622e-08
# Difference in final y velocity 4.884981308350689e-15
# Difference in final z velocity 8.58643593164436e-10
# Velocity Cross Product [-2.04337809e-09  1.81548594e-17 -6.41316725e-08]
# Maximum Jacobi Constant Deviation 2.3861801423663564e-11
# Maximum Hamiltonian Deviation 9.944752347526065e-08
# Angle 180.0

# %%
plt.figure()
plt.plot(x, y)
plt.axis("equal")
plt.xlim([-1.1, 1.2])
plt.ylim([-1, 1])
plt.xlabel("x [km]")
plt.ylabel("y [km]")
plt.title("Orbital Trajectory")
plt.grid(True)
z_err = np.max(np.abs(z)) # Maximum z error
print("Maximum Z Error", z_err)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Maximum Z Error 4.356763919260339e-08

# %%
def U(x, y, z):
    r1 = math.sqrt((x + mu)**2 + y**2 + z**2)
    r2 = math.sqrt((x - 1 + mu)**2 + y**2 + z**2)
    return -0.5*(x**2 + y**2) - (1 - mu)/r1 - mu/r2

C_vals = np.zeros((len(x), 1))
for i in range (len(x)):
    C_vals[i] = -2*U(x[i], y[i], z[i]) - (vx[i]**2 + vy[i]**2 + vz[i]**2)
C_err = np.ptp(C_vals) # Maximum Jacobi constant deviation
print("Maximum Jacobi Constant Deviation", C_err)
# Out:
# Maximum Jacobi Constant Deviation 2.3861801423663564e-11

# %%
C_mean = np.mean(C_vals)
print("Jacobi Mean Difference from Ideal", math.abs(C_mean - C_value))
plt.figure()
plt.plot(time, (C_vals - C_mean))
plt.title("Jacobi Constant")
plt.grid(True)
# Out:
# Jacobi Mean Difference from Ideal 0.767301840884898

# %%
hamiltonian = solution.phase[0].hamiltonian

plt.figure()
plt.plot(time, hamiltonian, linewidth=2)
plt.xlabel("Time")
plt.ylabel(r"Error in Hamiltonian")
plt.tight_layout()
plt.title("Hamiltonian")
plt.autoscale(axis='y')
plt.grid(True)
plt.show()

hamil_dev = np.ptp(hamiltonian)
print("Maximum Hamiltonian Deviation", hamil_dev)
# Out:
# Maximum Hamiltonian Deviation 9.944752347526065e-08

# %%
t_tick_days = np.arange(0, 45, 1)
t_tick = day_to_gen(t_tick_days)

from scipy.interpolate import interp1d

fx = interp1d(time, x, kind='cubic', bounds_error=False, fill_value="extrapolate")
fy = interp1d(time, y, kind='cubic', bounds_error=False, fill_value="extrapolate")
fz = interp1d(time, z, kind='cubic', bounds_error=False, fill_value="extrapolate")

x_ticks = fx(t_tick)
y_ticks = fy(t_tick)
z_ticks = fz(t_tick)

fig_3d = plt.figure()
ax = fig_3d.add_subplot(111, projection='3d')
plt.plot(x, y, z)
ax.set_box_aspect([1, 1, 1])
ax.set_xlim([-1.1, 1.2])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.scatter3D(x_ticks, y_ticks, z_ticks, marker='+', color='blue')
plt.title("Orbital Trajectory")
plt.grid(True)
ax.view_init(elev=30, azim=-60)
ax.view_init(elev=15, azim=-30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 t_tick_days = np.arange(0, 45, 1)
# ----> 2 t_tick = day_to_gen(t_tick_days)
#       4 from scipy.interpolate import interp1d
#       6 fx = interp1d(time, x, kind='cubic', bounds_error=False, fill_value="extrapolate")
#
# NameError: name 'day_to_gen' is not defined
